# %% [markdown]
# <a href="https://colab.research.google.com/github/iesous-kurios/adventofcode2020/blob/main/day_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
with open('input5.txt', 'r') as file:
    seat_ids = {int(seat, 2) for seat in file.read().translate(str.maketrans("FBLR", "0101")).splitlines()}
print(f"Part 1: {max(seat_ids)}\nPart 2: {(set(range(min(seat_ids), max(seat_ids))) - seat_ids).pop()}")

# %%
f = open('/content/input7.txt')

content = f.read()

# %%
parsed = content.split('\n')

# %%
for i in range(0, len(parsed)):
    parsed[i] = parsed[i].replace(' contain ', ':')

# %%
parsed[0]
# Out:
# 'dark indigo bags:2 clear indigo bags.'

# %%
bag_set = set()
for i in range(0, len(parsed)):
    bag_set.add(parsed[i])

# %%
len(bag_set)
# Out:
# 586

# %%
bag_set.pop()
# Out:
# 'vibrant coral bags:2 pale red bags, 3 bright teal bags, 5 striped bronze bags, 1 bright silver bag.'

# %%
help(bag_set)

# %%
len(parsed)
# Out:
# 595

# %%
for id,val in enumerate(bag_set): 
    print(id, val)
# Out:
# 0 posh tan bags:5 shiny tomato bags, 5 drab maroon bags, 5 vibrant maroon bags.
# 1 muted fuchsia bags:1 plaid black bag, 5 shiny yellow bags.
# 2 dark blue bags:4 shiny tomato bags.
# 3 posh turquoise bags:4 pale red bags, 3 mirrored brown bags, 3 mirrored indigo bags, 3 striped gold bags.
# 4 wavy teal bags:1 dim plum bag, 1 pale aqua bag, 2 posh purple bags, 2 pale orange bags.
# 5 plaid lime bags:4 muted silver bags, 2 vibrant tan bags.
# 6 faded beige bags:5 posh teal bags, 2 drab beige bags, 3 plaid lavender bags, 4 drab purple bags.
# 7 wavy tan bags:3 plaid chartreuse bags, 1 clear gold bag.
# 8 shiny gold bags:1 pale aqua bag, 3 dark cyan bags, 5 vibrant purple bags, 2 drab blue bags.
# 9 shiny maroon bags:2 pale green bags.
# 10 dim bronze bags:1 bright fuchsia bag.
# 11 plaid tomato bags:2 clear red bags, 2 dark tomato bags, 2 bright gold bags.
# 12 muted cyan bags:1 mirrored black bag, 2 clear orange bags, 5 light crimson bags, 2 mirrored teal bags.
# ...
